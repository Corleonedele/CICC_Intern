# %%
import openpyxl
from openpyxl.styles import PatternFill, colors

# %%
wb = openpyxl.load_workbook("./日报表_copy.xlsx")
风险控制指标情况_流水 = wb["风险控制指标情况_流水"]
私募种子基金持仓日报表_流水 = wb["私募种子基金持仓日报表_流水"]
风险控制指标情况_标准 =wb["风险控制指标情况_标准"]
私募种子基金持仓日报表_标准 = wb["私募种子基金持仓日报表_标准"]

# %%
start_row = 1
end_row = 31
start_col = 1
end_col = 8

pd_row = 0
pd_col = 0

for row in range(start_row, end_row+1):
    for col in range(start_col, end_col+1):
        position = (row, col)
        # v1 = 私募种子基金持仓日报表_流水.cell(row, col).value
        # v2 = 私募种子基金持仓日报表_标准.cell(row-pd_row, col-pd_col).value    

        v1 = 风险控制指标情况_流水.cell(row, col).value
        v2 = 风险控制指标情况_标准.cell(row-pd_row, col-pd_col).value  
        if v1 != v2: 
            if type(v1) == float and type(v2) == float:
                if round(v1, 4) == round(v2, 4):  continue
            # 私募种子基金持仓日报表_流水.cell(row, col).fill = PatternFill("solid", fgColor="1874CD")
            # 私募种子基金持仓日报表_标准.cell(row, col).fill = PatternFill("solid", fgColor="FFA300")

            风险控制指标情况_流水.cell(row, col).fill = PatternFill("solid", fgColor="1874CD")
            风险控制指标情况_标准.cell(row-pd_row, col).fill = PatternFill("solid", fgColor="FFA300")
            print(position, "流水表为: ", v1,"标准表为: ", v2)
# Out:
# (21, 2) 流水表为:   公司持有一种非权益类证券的规模与其总规模的比例前30名 标准表为:   公司持有一种非权益类证券的规模与其总规模的比例前10名
# (21, 6) 流水表为:  预警线12% 标准表为:  None
# (21, 7) 流水表为:  份额提供日期 标准表为:  None
# (21, 8) 流水表为:  总份额(万元) 标准表为:  None
# (22, 7) 流水表为:  2022-12-30 00:00:00 标准表为:  None
# (22, 8) 流水表为:  720.0054610000001 标准表为:  None
# (23, 7) 流水表为:  2022-12-30 00:00:00 标准表为:  None
# (23, 8) 流水表为:  1406.014103 标准表为:  None
# (24, 7) 流水表为:  2022-12-30 00:00:00 标准表为:  None
# (24, 8) 流水表为:  451.121794 标准表为:  None
# (25, 7) 流水表为:  2022-12-30 00:00:00 标准表为:  None
# (25, 8) 流水表为:  1048.257241 标准表为:  None
# (26, 7) 流水表为:  2022-12-30 00:00:00 标准表为:  None
# (26, 8) 流水表为:  5899.911671 标准表为:  None
# (27, 7) 流水表为:  2022-12-30 00:00:00 标准表为:  None
# (27, 8) 流水表为:  626.567713 标准表为:  None
# (28, 7) 流水表为:  2022-12-30 00:00:00 标准表为:  None
# (28, 8) 流水表为:  2378.6251 标准表为:  None
# (29, 7) 流水表为:  2022-12-30 00:00:00 标准表为:  None
# (29, 8) 流水表为:  4331.129784000001 标准表为:  None
# (30, 7) 流水表为:  2022-12-30 00:00:00 标准表为:  None
# ...

# %%
start_row = 52
end_row = 180
start_col = 1
end_col = 8

pd_row = 20
pd_col = 0

for row in range(start_row, end_row+1):
    for col in range(start_col, end_col+1):
        position = (row, col)
        # v1 = 私募种子基金持仓日报表_流水.cell(row, col).value
        # v2 = 私募种子基金持仓日报表_标准.cell(row-pd_row, col-pd_col).value    

        v1 = 风险控制指标情况_流水.cell(row, col).value
        v2 = 风险控制指标情况_标准.cell(row-pd_row, col-pd_col).value  
        if v1 != v2: 
            if type(v1) == float and type(v2) == float:
                if round(v1, 4) == round(v2, 4):  continue
            # 私募种子基金持仓日报表_流水.cell(row, col).fill = PatternFill("solid", fgColor="1874CD")
            # 私募种子基金持仓日报表_标准.cell(row, col).fill = PatternFill("solid", fgColor="FFA300")

            风险控制指标情况_流水.cell(row, col).fill = PatternFill("solid", fgColor="1874CD")
            风险控制指标情况_标准.cell(row-pd_row, col).fill = PatternFill("solid", fgColor="FFA300")
            print(position, "流水表为: ", v1,"标准表为: ", v2)
# Out:
# (53, 8) 流水表为:  豁免指标 标准表为:  None
# (54, 7) 流水表为:  2023-01-03 00:00:00 标准表为:  2023-01-05 00:00:00
# (54, 8) 流水表为:  0.2 标准表为:  *结合近期市场情况，以及管理人的策略特点，申请有条件继续持有该产品，若之后触及20%的绝对亏损，则进行全部赎回。
# (55, 8) 流水表为:  0.2 标准表为:  *若期间触及20%的绝对亏损（连续三个交易日），则进行赎回
# (60, 2) 流水表为:  #N/A 标准表为:  慈阳投资进取2号
# (60, 3) 流水表为:  #NAME? 标准表为:  -0.066147635854098
# (60, 6) 流水表为:  #NAME? 标准表为:  0.66147635854098
# (60, 7) 流水表为:  #N/A 标准表为:  2023-01-06 00:00:00
# (61, 2) 流水表为:  #N/A 标准表为:  易鑫安鑫安11期B
# (61, 3) 流水表为:  #NAME? 标准表为:  -0.06346520927824617
# (61, 6) 流水表为:  #NAME? 标准表为:  0.6346520927824617
# (61, 7) 流水表为:  #N/A 标准表为:  2023-01-05 00:00:00
# (63, 2) 流水表为:  #N/A 标准表为:  仙人掌盈沣远航臻选A
# (63, 6) 流水表为:  #NAME? 标准表为:  0.9062607497372377
# (63, 7) 流水表为:  #N/A 标准表为:  2023-01-05 00:00:00
# (63, 8) 流水表为:   标准表为:  *若期间触及20%的绝对亏损（连续三个交易日），则进行赎回
# (65, 7) 流水表为:  2023-01-03 00:00:00 标准表为:  2023-01-05 00:00:00
# (65, 8) 流水表为:  0.2 标准表为:  *结合近期市场情况，以及管理人的策略特点，申请有条件继续持有该产品，若之后触及20%的绝对亏损，则进行全部赎回。
# ...

# %%
start_row = 1
end_row = 180
start_col = 1
end_col = 30

pd_row = 0
pd_col = 0

for row in range(start_row, end_row+1):
    for col in range(start_col, end_col+1):
        position = (row, col)
        v1 = 私募种子基金持仓日报表_流水.cell(row, col).value
        v2 = 私募种子基金持仓日报表_标准.cell(row-pd_row, col-pd_col).value    

        # v1 = 风险控制指标情况_流水.cell(row, col).value
        # v2 = 风险控制指标情况_标准.cell(row-pd_row, col-pd_col).value  
        if v1 != v2: 
            if type(v1) == float and type(v2) == float:
                if round(v1, 4) == round(v2, 4):  continue
            私募种子基金持仓日报表_流水.cell(row, col).fill = PatternFill("solid", fgColor="1874CD")
            私募种子基金持仓日报表_标准.cell(row, col).fill = PatternFill("solid", fgColor="FFA300")

            # 风险控制指标情况_流水.cell(row, col).fill = PatternFill("solid", fgColor="1874CD")
            # 风险控制指标情况_标准.cell(row-pd_row, col).fill = PatternFill("solid", fgColor="FFA300")
            print(position, "流水表为: ", v1,"标准表为: ", v2)

wb.save("./日报表_copy_fill_v10.xlsx")
# Out:
# (5, 11) 流水表为:  13715.768555084396 标准表为:  13715.768120284396
# (5, 15) 流水表为:  94975.38 标准表为:  95175.38
# (5, 17) 流水表为:  94689.460116 标准表为:  94602.525926
# (5, 21) 流水表为:  210.86422299999685 标准表为:  297.7984129999968
# (6, 5) 流水表为:  531.8234998830999 标准表为:  531.8253013910996
# (7, 5) 流水表为:  599.0901230411002 标准表为:  599.0919245490995
# (8, 5) 流水表为:  65012.98929912331 标准表为:  65012.98886432331
# (9, 3) 流水表为:  95493.1185046297 标准表为:  95493.11806982971
# (15, 12) 流水表为:  初始成本价（元/份） 标准表为:  成本价（元/份）
# (15, 13) 流水表为:  本年度成本价 标准表为:  2022年12月30日单位净值
# (15, 30) 流水表为:  考核承担IC 标准表为:  None
# (16, 8) 流水表为:   标准表为:  None
# (16, 22) 流水表为:  0 标准表为:  None
# (16, 26) 流水表为:   标准表为:  None
# (16, 30) 流水表为:  张潇丹 标准表为:  D
# (17, 2) 流水表为:  一对一产品 标准表为:  None
# (17, 8) 流水表为:   标准表为:  None
# (17, 22) 流水表为:  0 标准表为:  None
# (17, 26) 流水表为:   标准表为:  None
# (17, 30) 流水表为:  万小妹 标准表为:  J
# (18, 2) 流水表为:  一对一产品 标准表为:  None
# (18, 8) 流水表为:   标准表为:  None
# (18, 22) 流水表为:  0 标准表为:  None
# (18, 26) 流水表为:   标准表为:  None
# ...
