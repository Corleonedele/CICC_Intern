# %%
from WindPy import w
import matplotlib.pyplot as plt

# %%
w.start("username=W1457909349;password=glh346glh;sitename=NJDX", waitTime=120)
# Out:
# Welcome to use Wind Quant API for Python (WindPy)!
#
# COPYRIGHT (C) 2021 WIND INFORMATION CO., LTD. ALL RIGHTS RESERVED.
# IN NO CIRCUMSTANCE SHALL WIND BE RESPONSIBLE FOR ANY DAMAGES OR LOSSES CAUSED BY USING WIND QUANT API FOR Python.
# .ErrorCode=0
# .Data=[OK!]

# %%
w_data = w.wsd("000905.SH","close","2021/8/13","2022/12/20")

# %%
w_data.Data[0]
zz500 = []
for i in w_data.Data[0]:
    zz500.append(i/60)

# %%
date1 = []
value1 = []

with open("data1.txt") as data1:
    for line in data1.readlines():
        info = line.split("\t")
        date1.append(info[0])
        value1.append(float(info[-1][:-1])*100)
date2 = []
value2 = []

with open("data2.txt") as data2:
    for line in data2.readlines():
        info = line.split("\t")
        date2.append(info[0])
        value2.append(float(info[-1][:-1])*100 - 10)
date3 = []
value3 = []

with open("data3.txt") as data3:
    for line in data3.readlines():
        info = line.split("\t")
        date3.append(info[0])
        value3.append(float(info[-1][:-1])*100)
value1
w.close()

# %%
#折线图
# x = [5,7,11,17,19,25]#点的横坐标
# x1 = [7,11,17,19]#点的横坐标
# k1 = [0.8222,0.918,0.9344,0.9262,0.9371,0.9353]#线1的纵坐标
# k2 = [0.9334,0.9435,0.9407,0.9453]#线2的纵坐标
# plt.plot(x,k1,'s-',color = 'r',label="ATT-RLSTM")#s-:方形
# plt.plot(x1,k2,'o-',color = 'g',label="CNN-RLSTM")#o-:圆形


plt.figure(figsize=(16,12),dpi=200)

plt.plot(date1,value1,linewidth=0.6,color = 'g',label="    ")
plt.plot(date2,value2,linewidth=0.6,color = 'r',label="    ")
plt.plot(date3,value3,linewidth=0.6,color = 'b',label="    ")
# plt.plot(date1,zz500,linewidth=0.5,color = 'purple', label="    ")
# plt.xlabel("Value")#横坐标名字
# plt.ylabel("Date")#纵坐标名字
xt = [date1[i] for i in range(1, len(date1), 24)]
plt.xticks(xt)

yt = [value1[i] for i in range(1, len(value1), 40)]
plt.yticks([])
plt.legend(loc = "best")#图例
# plt.show()
# Out:
# Connect to Sky fail. errCode:60
# Connect to Sky fail. errCode:60
# Connect to Sky fail. errCode:60
# Connect to Sky fail. errCode:60
